# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Linkedin_canada.csv")

# %%
df.head()
# Out:
#      applicationsCount   companyId companyName contractType  \
# 0  Over 200 applicants  11000395.0      Embarq    Full-time
# 1  Over 200 applicants    912833.0   Thumbtack    Full-time
# 2  Over 200 applicants  10064814.0    Clarifai    Full-time
# 3  Over 200 applicants   6637598.0        Drop    Full-time
# 4  Over 200 applicants   2681218.0      Logikk    Full-time
#
#                                          description   experienceLevel  \
# 0  About Embarq\n\nWe help VC-backed US startups ...  Mid-Senior level
# 1  A home is the biggest investment most people m...    Not Applicable
# 2  About The Company\n\nClarifai is a leading, fu...  Mid-Senior level
# 3  As a member of the Data Science team, you are ...    Not Applicable
# 4  Data Scientist - Computer Vision Tech Company ...  Mid-Senior level
#
#                    location    postedTime publishedAt salary  \
# 0            Quebec, Canada   2 weeks ago  05-01-2024    NaN
# ...

# %%
df.tail()
# Out:
#                     applicationsCount   companyId companyName contractType  \
# 270               Over 200 applicants   5045143.0  StackAdapt    Full-time
# 271                     45 applicants     14051.0     Kinaxis    Full-time
# 272               Over 200 applicants  93075952.0        Saks    Full-time
# 273                     57 applicants     14051.0     Kinaxis    Full-time
# 274  Be among the first 25 applicants         NaN         NaN          NaN
#
#                                            description experienceLevel  \
# 270  StackAdapt is a self-serve advertising platfor...     Entry level
# 271  About Kinaxis\n\nKinaxis is the global leader ...      Internship
# 272  Who We Are:\n\nSaks Cloud Services (SCS) is an...       Associate
# 273  About Kinaxis\n\nKinaxis is the global leader ...      Internship
# 274  Job responsibilities\n\n * Design & build scal...        Contract
#
#                       location   postedTime publishedAt salary  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 275 entries, 0 to 274
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   applicationsCount  275 non-null    object
#  1   companyId          274 non-null    float64
#  2   companyName        274 non-null    object
#  3   contractType       264 non-null    object
#  4   description        275 non-null    object
#  5   experienceLevel    275 non-null    object
#  6   location           275 non-null    object
#  7   postedTime         275 non-null    object
#  8   publishedAt        270 non-null    object
#  9   salary             13 non-null     object
#  10  sector             264 non-null    object
#  11  title              275 non-null    object
#  12  workType           264 non-null    object
# dtypes: float64(1), object(12)
# memory usage: 28.1+ KB

# %%
df.describe()
# Out:
#           companyId
# count  2.740000e+02
# mean   2.477687e+07
# std    3.199132e+07
# min    1.756000e+03
# 25%    9.260410e+05
# 50%    9.375816e+06
# 75%    5.162871e+07
# max    9.921892e+07

# %%
#check how many full-time or contract position

# %%
df.contractType.value_counts()
# Out:
# Full-time     235
# Contract       24
# Part-time       4
# Internship      1
# Name: contractType, dtype: int64

# %%
#experienced required or not

# %%
df.experienceLevel.value_counts()
# Out:
# Mid-Senior level    146
# Entry level          65
# Not Applicable       31
# Associate            19
# Full-time             7
# Internship            4
# Contract              2
# Part-time             1
# Name: experienceLevel, dtype: int64

# %%
#Jobs are based on different departments

# %%
df.workType.value_counts()
# Out:
# Engineering and Information Technology                               186
# Information Technology                                                28
# Engineering                                                           23
# Other                                                                  5
# Information Technology and Engineering                                 3
# Education, Engineering, and Marketing                                  3
# Quality Assurance                                                      2
# Marketing and Information Technology                                   1
# Research, Analyst, and Information Technology                          1
# Finance                                                                1
# Art/Creative and Information Technology                                1
# Information Technology and Research                                    1
# Information Technology and Management                                  1
# ...

# %%
sns.countplot(x=df.contractType,data=df)
plt.show()

# %%
df.salary.isnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 270    True
# 271    True
# 272    True
# 273    True
# 274    True
# Name: salary, Length: 275, dtype: bool

# %%
#check the total number of null values in the dataset

# %%
df.salary.isnull().sum()
# Out:
# 262

# %%
okay=df['salary'].replace(np.NaN,120000)

# %%
print(okay)
# Out:
# 0      120000
# 1      120000
# 2      120000
# 3      120000
# 4      120000
#         ...
# 270    120000
# 271    120000
# 272    120000
# 273    120000
# 274    120000
# Name: salary, Length: 275, dtype: object

# %%
plt.figure(figsize=(10, 5))
plt.pie(finalok, labels=finalok.index
        ,autopct='%1.1f%%',startangle=140, textprops={'fontsize': 10}, wedgeprops={'linewidth': 1, 'edgecolor': 'white'})
plt.title('Distribution of Job Postings by Position')
plt.tight_layout()
plt.show()

# %%
#Create the pivot table

# %%
pivot_table = pd.pivot_table(
    df,
    index='experienceLevel', 
    columns='contractType', 
    values='applicationsCount', 
    aggfunc='count',  # Aggregating by count
    fill_value=0  # Replace NaN with 0
)

# %%
pivot_table
# Out:
# contractType      Contract  Full-time  Internship  Part-time
# experienceLevel
# Associate                2         17           0          0
# Entry level              5         60           0          0
# Internship               0          3           0          0
# Mid-Senior level        16        126           0          4
# Not Applicable           1         29           1          0

# %%
#Create the Scatter plot

# %%
plt.figure(figsize=(10,6))
plt.scatter(df['experienceLevel'], df['location'],  alpha=0.6, edgecolor='k')
plt.title('scatter plot of experienceLevel vs  location ')
plt.grid(True)
plt.show()
